# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# Read in json files and create dataframes
filename = '2017-03-1319:13:44.248377.AppleFree.json'
data = pd.read_json(filename)
filename2 = '2017-03-1319:19:35.293296.ApplePaid.json'
data2 = pd.read_json(filename2)
filename3 = '2017-03-1412:37:30.296682.AppleFree.json'
data3 = pd.read_json(filename3)
filename4 = '2017-03-1412:41:10.250921.ApplePaid.json'
data4 = pd.read_json(filename4)

# %%
data
# Out:
#                                       Age Restriction           Category  \
# 0                                          Rated 12+           Utilities
# 1                                          Rated 12+       Photo & Video
# 2   You must be at least 17 years old to download ...      Photo & Video
# 3                                          Rated 12+       Photo & Video
# 4                                            Rated 4+             Sports
# 5                                          Rated 12+          Navigation
# 6                                            Rated 4+  Social Networking
# 7                                            Rated 4+              Games
# 8                                            Rated 4+             Travel
# 9                                            Rated 4+  Social Networking
# 10                                         Rated 12+               Music
# 11                                           Rated 4+      Entertainment
# ...

# %%
len(data)
# Out:
# 100

# %%
data2
# Out:
#                                       Age Restriction          Category  \
# 0                                           Rated 9+              Games
# 1                                           Rated 9+              Games
# 2                                          Rated 12+              Games
# 3                                           Rated 9+              Games
# 4                                            Rated 4+             Games
# 5                                            Rated 4+     Photo & Video
# 6                                          Rated 12+              Games
# 7                                            Rated 4+             Games
# 8                                            Rated 4+             Games
# 9                                          Rated 12+              Games
# 10                                           Rated 4+             Games
# 11                                           Rated 4+     Photo & Video
# ...

# %%
data3
# Out:
#                                       Age Restriction           Category  \
# 0                                            Rated 4+             Sports
# 1                                          Rated 12+           Utilities
# 2                                          Rated 12+       Photo & Video
# 3                                          Rated 12+       Photo & Video
# 4   You must be at least 17 years old to download ...      Photo & Video
# 5                                            Rated 4+  Social Networking
# 6                                          Rated 12+          Navigation
# 7                                            Rated 4+             Sports
# 8                                            Rated 4+  Social Networking
# 9                                            Rated 4+             Travel
# 10                                           Rated 4+              Games
# 11                                         Rated 12+               Music
# ...

# %%
data4
# Out:
#                                       Age Restriction          Category  \
# 0                                           Rated 9+              Games
# 1                                           Rated 9+              Games
# 2                                           Rated 9+              Games
# 3                                          Rated 12+              Games
# 4                                            Rated 4+     Photo & Video
# 5                                            Rated 4+             Games
# 6                                          Rated 12+              Games
# 7                                            Rated 4+             Games
# 8                                            Rated 4+             Games
# 9                                            Rated 4+          Business
# 10                                           Rated 4+             Games
# 11                                           Rated 4+     Photo & Video
# ...

# %%
set(data.Category)
# Out:
# {'Books',
#  'Entertainment',
#  'Finance',
#  'Food & Drink',
#  'Games',
#  'Health & Fitness',
#  'Lifestyle',
#  'Music',
#  'Navigation',
#  'News',
#  'Photo & Video',
#  'Productivity',
#  'Reference',
#  'Shopping',
#  'Social Networking',
#  'Sports',
#  'Travel',
#  'Utilities',
#  'Weather'}

# %%
set(data2.Category)
# Out:
# {'Business',
#  'Education',
#  'Entertainment',
#  'Games',
#  'Health & Fitness',
#  'Lifestyle',
#  'Music',
#  'Navigation',
#  'Photo & Video',
#  'Reference',
#  'Weather'}

# %%
set(data3.Category)
# Out:
# {'Books',
#  'Entertainment',
#  'Finance',
#  'Food & Drink',
#  'Games',
#  'Health & Fitness',
#  'Lifestyle',
#  'Music',
#  'Navigation',
#  'News',
#  'Photo & Video',
#  'Productivity',
#  'Reference',
#  'Shopping',
#  'Social Networking',
#  'Sports',
#  'Travel',
#  'Utilities',
#  'Weather'}

# %%
set(data4.Category)
# Out:
# {'Business',
#  'Education',
#  'Entertainment',
#  'Games',
#  'Health & Fitness',
#  'Lifestyle',
#  'Music',
#  'Navigation',
#  'Photo & Video',
#  'Reference',
#  'Travel',
#  'Weather'}

# %%
set(data.Seller)
# Out:
# {'1Button SARL',
#  'AMZN Mobile LLC',
#  'Alike Studio S.L.',
#  'Ambatana INC',
#  'BitMango Corporation',
#  'Bitstrips Inc.',
#  'ContextLogic Inc.',
#  'Credit Karma, Inc.',
#  'DistinctDev, Inc.',
#  'ESPN Inc.',
#  'Epic War LLC',
#  'Episode Interactive, LLC',
#  'Facebook, Inc.',
#  'Feelingtouch Inc.',
#  'Fitbit, Inc.',
#  'Flipagram, Inc.',
#  'Fortafy Games DMCC',
#  'Google, Inc.',
#  'Gram Games Limited',
#  'Groupon, Inc.',
#  'IMVU',
#  'Information Not Available',
#  'Instagram, Inc.',
#  'Kano Applications Inc.',
#  'Ketchapp',
#  'Kik Interactive Inc.',
#  'Kiloo',
#  "McDonald's Usa, LLC",
#  'Mediocre AB',
#  'Miniclip SA',
#  'Mobirate Studio Ltd',
#  'Monkey Squad, LLC.',
#  'Netflix, Inc.',
#  'Nintendo Co., Ltd.',
#  'Not Common Facts',
#  'OfferUp Inc.',
#  'PayPal, Inc.',
#  'Peak Games',
#  'PicsArt, Inc.',
#  'Pinterest, Inc.',
#  'Pixelberry Studios',
#  'Poptacular Ltd',
#  'Roblox Corporation',
#  'Ryan McLeod',
#  'Second Street Labs Inc',
# ...

# %%
set(data2.Seller)
# Out:
# {'1337 & Senri LLC',
#  '2K Sports',
#  '505 Games (US), Inc.',
#  'A&E Television Networks Mobile',
#  'Activision Publishing, Inc.',
#  'Afterlight Collective, Inc',
#  'Alec Thomson',
#  'Andreas Illiger',
#  'AppMoji, Inc.',
#  'Appsolute Inc.',
#  'Atari, Interactive',
#  'BP Mobile LLC',
#  'Butterscotch Shenanigans, LLC',
#  'CONSULIT KRZYSZTOF STARZECKI MICHAL MIZERA SPOLKA CYWILNA',
#  'Coffee Stain Studios AB',
#  'Disney Electronic Content, Inc.',
#  'Domus Technica BV',
#  'Electronic Arts Inc.',
#  'Elokence.com',
#  'Fireproof Studios Limited',
#  'Flipline IDS LLC',
#  'GAMEBRAIN YAZILIM TEKNOLOJILERI LIMITED SIRKETI',
#  'GHI Media, LLC',
#  'GIANTS Software GmbH',
#  'Glitche Limited',
#  'Hubert Sliwka',
#  'IAC Search & Media Europe Ltd.',
#  'Igor Kalicinski',
#  'Information Not Available',
#  'Joel McDonald',
#  'Kaiparasoft Ltd',
#  'Kumobius Pty Ltd',
#  'LIMBO ApS / Playdead ApS',
#  'Lightricks Ltd.',
#  'Lima Sky',
#  'Loveshack Entertainment Pty Ltd',
# ...

# %%
data
# Out:
#                                       Age Restriction           Category  \
# 0                                          Rated 12+           Utilities
# 1                                          Rated 12+       Photo & Video
# 2   You must be at least 17 years old to download ...      Photo & Video
# 3                                          Rated 12+       Photo & Video
